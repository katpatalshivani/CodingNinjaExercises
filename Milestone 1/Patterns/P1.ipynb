# %% [markdown]
# 4444
# 4444
# 4444
# 4444

# %%
N=int(input())

i=1

while i<=N:
    j=1
    while j<=N:
        print(N, end='')
        j=j+1
       
    print()
    i=i+1
# Out:
# 3
# 333
# 333
# 333

# %% [markdown]
# *
# **
# ***
# ****

# %%
n=int(input())
i=1

while i<=n:
    j=1
    
    while j<=i:
        print('*',end='')
        j=j+1
        
    print()
    i=i+1
# Out:
# 4
# *
# **
# ***
# ****

# %% [markdown]
# 1
# 22
# 333
# 4444

# %%
n=int(input())
i=1

while i<=n:
    j=1
    
    while j<=i:
        print(i,end='')
        j=j+1
        
    print()
    i=i+1
# Out:
# 4
# 1
# 22
# 333
# 4444

# %% [markdown]
# 1
# 21
# 321
# 4321

# %%
n=int(input())
i=1

while i<=n:
    j=1
    p=i
    while j<=i:
        print(p, end='')
        j=j+1
        p=p-1
    print()
    i=i+1
# Out:
# 4
# 1
# 21
# 321
# 4321

# %% [markdown]
# A
# BC
# CDE
# DEFG

# %%
n=int(input())

i=1

while i<=n:
    j=1
    strt_ch=chr(ord('A')+i-1)
    while j<=i:
        ch=chr(ord(strt_ch)+j-1)
        print(ch, end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# A
# BC
# CDE
# DEFG

# %% [markdown]
# E
# DE
# CDE
# BCDE
# ABCDE

# %% [markdown]
# 1
# 11
# 111
# 1111

# %%
n=int(input())
i=1

while i<=n:
    j=1
    while j<=i:
        print('1',end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# 1
# 11
# 111
# 1111

# %% [markdown]
# 1
# 11
# 121
# 1221

# %%
n=int(input())
i=2
print("1")
print()

while i<=n:
    t=i-1
   # j=1
    
    while j<=i:
        j=1
        print("1",end='')
        
        if t>0 and t<i:
            print("2",end='')
            t=t+1
            
        print("1",end='')
        
        j=j+1
    print()
    i=i+1
# Out:
# 3
# 1
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 6>()
#      15         print("2",end='')
#      16         t=t+1
# ---> 18     print("1",end='')
#      20     j=j+1
#      21 print()
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
# ...

# %%
n=int(input())

i=1


while i<=n:
    
    if i==1:
        print("1",end="")
        #print()
   
        
    else:
        j=i

        while j<=i:
            print(i-1,end="")
            j=j+1

        k=1
        while k<=i-2:
            print("0",end='')
            k=k+1
        print(i-1,end="")
    print()
    i=i+1
# Out:
# 5
# 1
# 11
# 202
# 3003
# 40004

# %%
n=int(input())

i=1


while i<=n:
    
    if i==1:
        print("1",end="")
        #print()
   
        
    else:
        j=i
        

        while j<=i:
            print("1",end="")
            j=j+1

        k=1
        while k<=i-2:
            print("2",end='')
            k=k+1
        print("1",end="")
    print()
    i=i+1
# Out:
# 7
# 1
# 11
# 121
# 1221
# 12221
# 122221
# 1222221

# %%
n=int(input())

i=1
t=int(n+65)

while i<=n:
    #s=t
    j=i
    
    while j<=i:
        print(chr(t),end="")
        j=j+1
        s=t
        t=t-1
        
    k=1
    while k<=i-1 and k>0:
        print(chr(s+1),end="")
        s=s+1
        k=k+1
        
        
    print()
    i=i+1
# Out:
# 4
# E
# DE
# CDE
# BCDE
