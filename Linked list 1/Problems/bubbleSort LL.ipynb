# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None



def bubbleSort(head) :
	#Your code goes here
    if head is None:
        return -1
    
    if head.next is None:
        return head
    
    prev=None
    curr=head
    nxt=head.next
    count = 0
    if prev == None and curr.data >nxt.data:
        curr.next= nxt.next
        nxt.next = curr
        curr = next
        head = curr
        prev= curr
        count = count +1
        
        
    else:
        if curr.data >
        
    
    












def takeInput() :
    head = None
    tail = None

    datas = [int (x) for x in input().split()]

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head



def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
head = takeInput()
head = bubbleSort(head)
printLinkedList(head)
# Out:
# 10 9 8 -1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 80>()
#      78 head = takeInput()
#      79 head = bubbleSort(head)
# ---> 80 printLinkedList(head)
#
# Input In [6], in printLinkedList(head)
#      68 def printLinkedList(head) :
#      70     while head is not None :
# ---> 71         print(head.data, end = " ")
#      72         head = head.next
#      74     print()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'data'
