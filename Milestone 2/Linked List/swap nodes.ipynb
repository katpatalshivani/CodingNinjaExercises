# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None



def swapNodes(head, x, y) :
	#Your code goes here
    if i==j:
        return head
    curr=head
    prev=previ=curri=prevj=currj=None
    c=0
    while curr!=None:
        if c==i:
            previ=prev
            curri=curr
        elif c==j:
            prevj=prev
            currj=curr
        prev=curr
        curr=curr.next
        c+=1
    if curri==None or currj==None:
        return 
    if previ==None:
        head=currj
    else:
        previ.next=currj
    if prevj==None:
        head=curri
    else:
        prevj.next=curri
    curr=curri.next
    curri.next=currj.next
    currj.next=curr
    return head


  
   
    
            
        
        
    




























#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = [int(x) for x in input().split()]
    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head  




def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
  
head = takeInput()
#x_y = stdin.readline().strip().split(" ")

i = int(input())
j = int(input())

newHead = swapNodes(head, i, j)
printLinkedList(newHead)
# Out:
# 10 20 30 50 40 60 -1
# 3
# 4
# 10 20 30 40 50 60

# %%
'''
copy and paste above code


 The head node is swapped with the first node in the list, and then it swaps each subsequent node with its predecessor until it reaches the last one.


The code starts by setting curr to be equal to head.


It then sets previ and curri to be equal to prev and curr respectively, which are initialized as None.


Then while loop iterates through all of the nodes in order from head down until it finds one that isn't None (curr).


If c==i or c==j, then this means that we're at an end point where we need to swap back around so that we can continue on our way again.


In these cases, previ and curri are set equal to their respective predecessors (prev) and successors (curr), respectively.


Otherwise, if c==j or c==i, then this means that there's another iteration left before reaching an end point so we just keep going without swapping anything else out for now.


After every iteration through the loop has been completed once more time, either because they've reached an end point or because they haven't yet found a non-None value in their current position within the list 


The code will swap the nodes of head and i, if i==j.


 If i==j, then the code will return head.

'''
